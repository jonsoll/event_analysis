# %%
import os
import pandas as pd
import datetime
from datetime import timedelta
import importlib
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
def to_eod(df):
    return df.loc[df.groupby(['Ticker', 'TradeCategory', 'eventDateTime', 'tradeDate','id'])['tradeTime'].idxmax()]

# %%
# load and preprocess

os.chdir('S:\Jon Soll\TradeLog')
tradelog = pd.read_excel('Tradelog.xlsx')

mask =  (tradelog['Date'] >= pd.Timestamp(datetime.date(2018, 5, 1))) & \
        (tradelog['Closed Position'] == 1) & \
        (tradelog['Result for Stock'].isin([1, -1])) & \
        (~tradelog['EventTime'].isna()) & \
        (~tradelog['TradeCategory'].isna())
variables = ['Date', 'EventTime', 'Ticker', 'TradeCategory', 'Result for Stock']

df = tradelog[mask]
df = df[variables]

df.loc[df['EventTime'] == "BMO", 'EventTime'] = datetime.time(8, 30)
df.loc[df['EventTime'] == "AMC", 'EventTime'] = datetime.time(16, 30)
df['EventDateTime'] = [datetime.datetime.combine(date, time) for (date, time) in zip(df['Date'], df['EventTime'])]
df = df.drop_duplicates()
df['id'] = np.arange(len(df)) + 1
print(df.shape)
df.head(30)
# Out:
# (164, 7)
#           Date EventTime  Ticker         TradeCategory Result for Stock  \
# 107 2018-05-01  13:59:00    AXSM  INSTITUTION DECISION               -1
# 110 2018-05-01  11:05:00     GSM                   ITC                1
# 129 2018-05-02  15:44:00    NVRO  INSTITUTION DECISION               -1
# 130 2018-05-03  09:43:00    ABBV  INSTITUTION DECISION                1
# 132 2018-05-03  08:30:00    AMGN          FDA DECISION                1
# 140 2018-05-03  08:30:00   BIIB           FDA DECISION                1
# 141 2018-05-03  08:30:00    EGRX           SHARED DRUG                1
# 142 2018-05-03  16:30:00    FLXN         REIMBURSEMENT                1
# 144 2018-05-03  16:30:00    HALO         REIMBURSEMENT                1
# 145 2018-05-03  16:30:00    IRWD            SETTLEMENT                1
# 146 2018-05-03  16:30:00    JAZZ         REIMBURSEMENT                1
# 158 2018-05-04  13:18:00    GILD  INSTITUTION DECISION                1
# 159 2018-05-07  08:30:00    AMAG         REIMBURSEMENT               -1
# 164 2018-05-07  08:30:00    HRTX         REIMBURSEMENT                1
# 171 2018-05-07  08:30:00  MOR GY         REIMBURSEMENT                1
# 173 2018-05-07  08:30:00    ONCE         REIMBURSEMENT                1
# 177 2018-05-08  08:30:00    ALXN       PATENT ISSUANCE               -1
# 180 2018-05-08  09:42:00    CELG  INSTITUTION DECISION                1
# 185 2018-05-08  10:01:00    IDCC                 OTHER                1
# 190 2018-05-08  10:01:00     VHC                 OTHER                1
# 191 2018-05-08  10:46:00    VIVE  INSTITUTION DECISION               -1
# 205 2018-05-09  08:30:00    COOL         REIMBURSEMENT                1
# 207 2018-05-09  14:53:00    FSLR        COURT DECISION                1
# 208 2018-05-09  08:30:00    IART         REIMBURSEMENT                1
# 209 2018-05-09  08:30:00    MDXG         REIMBURSEMENT               -1
# 210 2018-05-09  08:30:00    PACB            SETTLEMENT                1
# 211 2018-05-09  08:30:00    PCRX         REIMBURSEMENT               -1
# 214 2018-05-09  08:30:00   RHHBY         REIMBURSEMENT               -1
# 220 2018-05-09  14:53:00    SPWR        COURT DECISION                1
# 222 2018-06-07  16:30:00    ACOR        COURT DECISION                1
#
#           EventDateTime  id
# 107 2018-05-01 13:59:00   1
# 110 2018-05-01 11:05:00   2
# 129 2018-05-02 15:44:00   3
# 130 2018-05-03 09:43:00   4
# 132 2018-05-03 08:30:00   5
# 140 2018-05-03 08:30:00   6
# 141 2018-05-03 08:30:00   7
# 142 2018-05-03 16:30:00   8
# 144 2018-05-03 16:30:00   9
# 145 2018-05-03 16:30:00  10
# 146 2018-05-03 16:30:00  11
# 158 2018-05-04 13:18:00  12
# 159 2018-05-07 08:30:00  13
# 164 2018-05-07 08:30:00  14
# 171 2018-05-07 08:30:00  15
# 173 2018-05-07 08:30:00  16
# 177 2018-05-08 08:30:00  17
# 180 2018-05-08 09:42:00  18
# 185 2018-05-08 10:01:00  19
# 190 2018-05-08 10:01:00  20
# 191 2018-05-08 10:46:00  21
# 205 2018-05-09 08:30:00  22
# 207 2018-05-09 14:53:00  23
# 208 2018-05-09 08:30:00  24
# 209 2018-05-09 08:30:00  25
# 210 2018-05-09 08:30:00  26
# 211 2018-05-09 08:30:00  27
# 214 2018-05-09 08:30:00  28
# 220 2018-05-09 14:53:00  29
# 222 2018-06-07 16:30:00  30

# %%
os.chdir('P:\Projects\event_analysis')
import IntradayPrice2
importlib.reload(IntradayPrice2)
from IntradayPrice2 import request_price_data

# %%
# pull data from Bloomberg

# df = df[:50]
tickers        = df['Ticker']
eventDatetimes = df['EventDateTime']

interval = 15
num_days = 5
data = pd.concat(request_price_data(tickers, eventDatetimes, num_days=num_days, interval = interval))
data['tradeDate'] = [d.date() for d in data['tradeTime']]
# Out:
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Connecting to localhost:8194
#
# 1/164:  Pulling data for event that happened at 2018-05-01 13:59:00 with AXSM
# 2/164:  Pulling data for event that happened at 2018-05-01 11:05:00 with GSM
# 3/164:  Pulling data for event that happened at 2018-05-02 15:44:00 with NVRO
# 4/164:  Pulling data for event that happened at 2018-05-03 09:43:00 with ABBV
# 5/164:  Pulling data for event that happened at 2018-05-03 08:30:00 with AMGN
# 6/164:  Pulling data for event that happened at 2018-05-03 08:30:00 with BIIB
# 7/164:  Pulling data for event that happened at 2018-05-03 08:30:00 with EGRX
# 8/164:  Pulling data for event that happened at 2018-05-03 16:30:00 with FLXN
# 9/164:  Pulling data for event that happened at 2018-05-03 16:30:00 with HALO
# 10/164:  Pulling data for event that happened at 2018-05-03 16:30:00 with IRWD
# 11/164:  Pulling data for event that happened at 2018-05-03 16:30:00 with JAZZ
# 12/164:  Pulling data for event that happened at 2018-05-04 13:18:00 with GILD
# 13/164:  Pulling data for event that happened at 2018-05-07 08:30:00 with AMAG
# 14/164:  Pulling data for event that happened at 2018-05-07 08:30:00 with HRTX
# 15/164:  Pulling data for event that happened at 2018-05-07 08:30:00 with MOR GY
# 16/164:  Pulling data for event that happened at 2018-05-07 08:30:00 with ONCE
# 17/164:  Pulling data for event that happened at 2018-05-08 08:30:00 with ALXN
# 18/164:  Pulling data for event that happened at 2018-05-08 09:42:00 with CELG
# 19/164:  Pulling data for event that happened at 2018-05-08 10:01:00 with IDCC
# 20/164:  Pulling data for event that happened at 2018-05-08 10:01:00 with VHC
# 21/164:  Pulling data for event that happened at 2018-05-08 10:46:00 with VIVE
# 22/164:  Pulling data for event that happened at 2018-05-09 08:30:00 with COOL
# Error: 'time'
# 23/164:  Pulling data for event that happened at 2018-05-09 14:53:00 with FSLR
# 24/164:  Pulling data for event that happened at 2018-05-09 08:30:00 with IART
# 25/164:  Pulling data for event that happened at 2018-05-09 08:30:00 with MDXG
# 26/164:  Pulling data for event that happened at 2018-05-09 08:30:00 with PACB
# 27/164:  Pulling data for event that happened at 2018-05-09 08:30:00 with PCRX
# 28/164:  Pulling data for event that happened at 2018-05-09 08:30:00 with RHHBY
# 29/164:  Pulling data for event that happened at 2018-05-09 14:53:00 with SPWR
# 30/164:  Pulling data for event that happened at 2018-06-07 16:30:00 with ACOR
# 31/164:  Pulling data for event that happened at 2018-05-14 08:30:00 with BIIB
# 32/164:  Pulling data for event that happened at 2018-05-14 08:30:00 with INDV
# Error: 'time'
# 33/164:  Pulling data for event that happened at 2018-05-15 09:46:00 with XENT
# 34/164:  Pulling data for event that happened at 2018-05-17 16:30:00 with ALDR
# 35/164:  Pulling data for event that happened at 2018-05-17 12:57:00 with ANET
# 36/164:  Pulling data for event that happened at 2018-05-17 11:31:00 with CBS
# 37/164:  Pulling data for event that happened at 2018-05-17 08:30:00 with CORT
# 38/164:  Pulling data for event that happened at 2018-05-17 08:30:00 with MNK
# 39/164:  Pulling data for event that happened at 2018-05-17 11:31:00 with VIAB
# 40/164:  Pulling data for event that happened at 2018-05-22 16:30:00 with KRE
# 41/164:  Pulling data for event that happened at 2018-05-23 13:15:00 with WOR
# 42/164:  Pulling data for event that happened at 2018-05-24 16:30:00 with AMRN
# 43/164:  Pulling data for event that happened at 2018-05-24 10:19:00 with INGN
# 44/164:  Pulling data for event that happened at 2018-05-24 08:30:00 with OMER
# 45/164:  Pulling data for event that happened at 2018-05-30 08:30:00 with ACRS
# 46/164:  Pulling data for event that happened at 2018-05-30 14:54:00 with INSY
# 47/164:  Pulling data for event that happened at 2018-05-30 15:16:00 with NUAN
# 48/164:  Pulling data for event that happened at 2018-05-30 16:30:00 with VRTX
# 49/164:  Pulling data for event that happened at 2018-05-31 08:30:00 with EIX
# 50/164:  Pulling data for event that happened at 2018-05-31 14:16:00 with NTLA
# 51/164:  Pulling data for event that happened at 2018-05-31 16:30:00 with PGNX
# 52/164:  Pulling data for event that happened at 2018-05-31 10:30:00 with VIVE
# 53/164:  Pulling data for event that happened at 2018-06-01 08:30:00 with MDXG
# 54/164:  Pulling data for event that happened at 2018-06-04 16:30:00 with AMGN
# 55/164:  Pulling data for event that happened at 2018-06-06 08:30:00 with HZNP
# 56/164:  Pulling data for event that happened at 2018-06-07 08:30:00 with AMBC
# 57/164:  Pulling data for event that happened at 2018-06-08 14:54:00 with EGRX
# 58/164:  Pulling data for event that happened at 2018-06-12 16:30:00 with MRK
# 59/164:  Pulling data for event that happened at 2018-06-12 08:30:00 with PDLI
# 60/164:  Pulling data for event that happened at 2018-06-12 16:30:00 with TWX
# 61/164:  Pulling data for event that happened at 2018-06-14 11:01:00 with HZNP
# 62/164:  Pulling data for event that happened at 2018-06-14 08:30:00 with RTRX
# 63/164:  Pulling data for event that happened at 2018-06-15 11:33:00 with QCOM
# 64/164:  Pulling data for event that happened at 2018-06-18 08:30:00 with JAZZ
# 65/164:  Pulling data for event that happened at 2018-06-20 14:14:00 with MRK
# 66/164:  Pulling data for event that happened at 2018-06-25 10:11:00 with AXP
# 67/164:  Pulling data for event that happened at 2018-06-25 10:02:00 with DXCM
# 68/164:  Pulling data for event that happened at 2018-06-25 12:20:00 with GWPH
# 69/164:  Pulling data for event that happened at 2018-06-26 08:30:00 with IRBT
# 70/164:  Pulling data for event that happened at 2018-06-27 13:32:00 with ANET
# 71/164:  Pulling data for event that happened at 2018-07-02 08:30:00 with DVMT
# 72/164:  Pulling data for event that happened at 2018-07-03 09:45:00 with MNK
# 73/164:  Pulling data for event that happened at 2018-07-03 10:19:00 with POWI
# 74/164:  Pulling data for event that happened at 2018-07-05 08:30:00 with HZNP
# 75/164:  Pulling data for event that happened at 2018-07-09 08:30:00 with EGRX
# 76/164:  Pulling data for event that happened at 2018-07-09 08:30:00 with IMMR
# 77/164:  Pulling data for event that happened at 2018-07-11 08:30:00 with FMI
# 78/164:  Pulling data for event that happened at 2018-07-11 15:23:00 with NVS
# 79/164:  Pulling data for event that happened at 2018-07-13 08:30:00 with CHRW
# 80/164:  Pulling data for event that happened at 2018-07-13 14:25:00 with JNJ
# 81/164:  Pulling data for event that happened at 2018-07-16 08:30:00 with RDY
# 82/164:  Pulling data for event that happened at 2018-07-17 08:30:00 with BTG LN
# 83/164:  Pulling data for event that happened at 2018-07-17 08:30:00 with GE9
# Error: Choice sub-element not found for name 'barData'. (0x00020002)
# 84/164:  Pulling data for event that happened at 2018-07-18 16:30:00 with FMI
# 85/164:  Pulling data for event that happened at 2018-07-18 08:30:00 with LGND
# 86/164:  Pulling data for event that happened at 2018-07-18 08:30:00 with MNTA
# 87/164:  Pulling data for event that happened at 2018-07-27 13:41:00 with GRPN
# 88/164:  Pulling data for event that happened at 2018-07-24 15:12:00 with NVRO
# 89/164:  Pulling data for event that happened at 2018-07-25 11:13:00 with ACOR
# 90/164:  Pulling data for event that happened at 2018-07-25 08:30:00 with INVA
# 91/164:  Pulling data for event that happened at 2018-07-25 10:13:00 with OMER
# 92/164:  Pulling data for event that happened at 2018-07-26 08:30:00 with EYES
# 93/164:  Pulling data for event that happened at 2018-07-30 12:43:00 with INDV
# Error: 'time'
# 94/164:  Pulling data for event that happened at 2018-07-26 08:30:00 with IRWD
# 95/164:  Pulling data for event that happened at 2018-07-27 11:47:00 with AMGN
# 96/164:  Pulling data for event that happened at 2018-07-27 08:30:00 with ENTA
# 97/164:  Pulling data for event that happened at 2018-07-27 11:28:00 with HOLX
# 98/164:  Pulling data for event that happened at 2018-07-30 12:41:00 with RDY
# 99/164:  Pulling data for event that happened at 2018-08-02 08:30:00 with QTRH
# 100/164:  Pulling data for event that happened at 2018-08-03 08:30:00 with EGRX
# 101/164:  Pulling data for event that happened at 2018-08-03 08:30:00 with JAZZ
# 102/164:  Pulling data for event that happened at 2018-08-03 08:30:00 with TEVA
# 103/164:  Pulling data for event that happened at 2018-08-06 10:18:00 with NE
# 104/164:  Pulling data for event that happened at 2018-08-07 08:30:00 with SOBI
# Error: 'time'
# 105/164:  Pulling data for event that happened at 2018-08-07 14:19:00 with VHC
# 106/164:  Pulling data for event that happened at 2018-08-08 10:00:00 with AGN
# 107/164:  Pulling data for event that happened at 2018-08-09 08:30:00 with MNTA
# 108/164:  Pulling data for event that happened at 2018-08-09 08:30:00 with UTHR
# 109/164:  Pulling data for event that happened at 2018-08-13 11:15:00 with ENDP
# 110/164:  Pulling data for event that happened at 2018-08-14 08:30:00 with MTSI
# 111/164:  Pulling data for event that happened at 2018-08-15 12:01:00 with AGN
# 112/164:  Pulling data for event that happened at 2018-08-20 14:54:00 with AMGN
# 113/164:  Pulling data for event that happened at 2018-08-28 16:30:00 with ASRT
# 114/164:  Pulling data for event that happened at 2018-08-28 08:30:00 with ZBH
# 115/164:  Pulling data for event that happened at 2018-08-29 13:02:00 with CVSI
# 116/164:  Pulling data for event that happened at 2018-08-29 08:30:00 with PCG
# 117/164:  Pulling data for event that happened at 2018-08-30 10:07:00 with CRON
# 118/164:  Pulling data for event that happened at 2018-09-04 16:30:00 with COLL
# 119/164:  Pulling data for event that happened at 2018-09-04 12:06:00 with TLRY
# 120/164:  Pulling data for event that happened at 2018-09-05 10:45:00 with IRBT
# 121/164:  Pulling data for event that happened at 2018-09-05 08:30:00 with QCOM
# 122/164:  Pulling data for event that happened at 2018-09-06 08:30:00 with CBS
# 123/164:  Pulling data for event that happened at 2018-09-06 08:30:00 with SUPN
# 124/164:  Pulling data for event that happened at 2018-09-06 08:30:00 with VIAB
# 125/164:  Pulling data for event that happened at 2018-09-07 08:30:00 with AAPL
# 126/164:  Pulling data for event that happened at 2018-09-07 08:30:00 with ABMD
# 127/164:  Pulling data for event that happened at 2018-09-07 16:30:00 with BIIB
# 128/164:  Pulling data for event that happened at 2018-09-10 10:10:00 with ACOR
# 129/164:  Pulling data for event that happened at 2018-09-10 10:10:00 with EDIT
# 130/164:  Pulling data for event that happened at 2018-09-10 10:10:00 with ORX
# Error: 'time'
# 131/164:  Pulling data for event that happened at 2018-09-12 10:20:00 with TLRY
# 132/164:  Pulling data for event that happened at 2018-09-13 08:30:00 with ACOR
# 133/164:  Pulling data for event that happened at 2018-09-13 08:30:00 with IRBT
# 134/164:  Pulling data for event that happened at 2018-09-18 10:06:00 with P
# 135/164:  Pulling data for event that happened at 2018-09-18 11:42:00 with TSLA
# 136/164:  Pulling data for event that happened at 2018-09-19 08:30:00 with MNK
# 137/164:  Pulling data for event that happened at 2018-09-20 10:07:00 with ABBV
# 138/164:  Pulling data for event that happened at 2018-09-21 15:53:00 with SCG
# 139/164:  Pulling data for event that happened at 2018-09-24 10:09:00 with DGX
# 140/164:  Pulling data for event that happened at 2018-09-25 11:57:00 with PACB
# 141/164:  Pulling data for event that happened at 2018-09-26 12:05:00 with ALGN
# 142/164:  Pulling data for event that happened at 2018-09-28 14:40:00 with QCOM
# 143/164:  Pulling data for event that happened at 2018-10-01 08:30:00 with COLL
# 144/164:  Pulling data for event that happened at 2018-10-04 10:00:00 with MFC
# 145/164:  Pulling data for event that happened at 2018-10-04 09:46:00 with N
# Error: 'time'
# 146/164:  Pulling data for event that happened at 2018-10-04 09:46:00 with NXTTF
# 147/164:  Pulling data for event that happened at 2018-10-08 10:36:00 with PYX
# 148/164:  Pulling data for event that happened at 2018-10-10 08:30:00 with 4506 JP
# 149/164:  Pulling data for event that happened at 2018-10-10 13:10:00 with ALNY
# 150/164:  Pulling data for event that happened at 2018-10-10 16:30:00 with BAYN
# Error: 'time'
# 151/164:  Pulling data for event that happened at 2018-10-11 16:30:00 with ABBV
# 152/164:  Pulling data for event that happened at 2018-10-11 16:30:00 with JAZZ
# 153/164:  Pulling data for event that happened at 2018-10-12 09:45:00 with MNTA
# 154/164:  Pulling data for event that happened at 2018-10-12 09:45:00 with TEVA
# 155/164:  Pulling data for event that happened at 2018-10-16 08:30:00 with IMMR
# 156/164:  Pulling data for event that happened at 2018-10-17 08:30:00 with DVA
# 157/164:  Pulling data for event that happened at 2018-10-18 07:08:00 with PTE
# 158/164:  Pulling data for event that happened at 2018-10-01 08:00:00 with AKRX
# 159/164:  Pulling data for event that happened at 2018-10-23 08:00:00 with EW
# 160/164:  Pulling data for event that happened at 2018-10-25 14:00:00 with EGRX
# 161/164:  Pulling data for event that happened at 2018-10-25 14:00:00 with AMGN
# 162/164:  Pulling data for event that happened at 2018-10-25 14:00:00 with REGN
# 163/164:  Pulling data for event that happened at 2018-10-30 08:30:00 with ALKS
# 164/164:  Pulling data for event that happened at 2018-11-02 09:50:00 with W
# Session Closed

# %%
# combine metadata and price data
df_comb = data.merge(df[['Ticker', 'EventDateTime', 'Result for Stock', 'TradeCategory', 'id']],
           left_on=['Ticker', 'eventDateTime'], right_on=['Ticker', 'EventDateTime'])

# get EOD prices 
variables = ['id', 'Ticker', 'EventDateTime', 'TradeCategory', 'Result for Stock', 'tradeDate', 'tradeTime', 'close']
df_timeseries = to_eod(df_comb)[variables]
df_timeseries = df_comb[variables]

# get prices at time of event
df_eventPrice = df_comb.loc[df_comb.groupby(['id'])['tradeTime'].idxmin()][['id', 'close']]
df_eventPrice.columns = ['id', 'eventPrice']

# calculate returns
df_ret = df_timeseries.merge(df_eventPrice, left_on = 'id', right_on = 'id')
df_ret['return'] = (df_ret['close'] - df_ret['eventPrice']) / df_ret['eventPrice']
df_ret['t_min'] = (df_ret.groupby('id')['tradeTime'].rank(method='min') * interval - interval) 
df_ret['t_hr'] = (df_ret.groupby('id')['tradeTime'].rank(method='min') * interval - interval) / 60
# df_ret['t'] = [str(timedelta(minutes=x))[:-3] for x in df_ret['t']]

# df_ret.loc[df_ret.groupby(['tradeDate', 'id'])['tradeTime'].idxmax()].sort_values(by=['id', 'tradeDate'])
# df_ret.loc[df_ret.groupby(['tradeDate', 'id'])['tradeTime'].idxmin()].sort_values(by=['id', 'tradeDate'])
# df_ret

# %%
def time_diff(ts):
    diff = ts.diff() #/ np.timedelta64(1, 'm')
    return pd.concat([ts, diff], axis = 1)

# %%
time_diff(df_ret.tradeTime[0:70])
# Out:
#              tradeTime tradeTime
# 0  2018-05-01 13:59:00       NaT
# 1  2018-05-01 14:14:00  00:15:00
# 2  2018-05-01 14:29:00  00:15:00
# 3  2018-05-01 14:44:00  00:15:00
# 4  2018-05-01 14:59:00  00:15:00
# 5  2018-05-01 15:14:00  00:15:00
# 6  2018-05-01 15:29:00  00:15:00
# 7  2018-05-01 15:44:00  00:15:00
# 8  2018-05-01 15:59:00  00:15:00
# 9  2018-05-01 16:29:00  00:30:00
# 10 2018-05-02 09:30:00  17:01:00
# 11 2018-05-02 09:45:00  00:15:00
# 12 2018-05-02 10:00:00  00:15:00
# 13 2018-05-02 10:15:00  00:15:00
# 14 2018-05-02 10:30:00  00:15:00
# 15 2018-05-02 10:45:00  00:15:00
# 16 2018-05-02 11:00:00  00:15:00
# 17 2018-05-02 11:15:00  00:15:00
# 18 2018-05-02 11:30:00  00:15:00
# 19 2018-05-02 11:45:00  00:15:00
# 20 2018-05-02 12:00:00  00:15:00
# 21 2018-05-02 12:15:00  00:15:00
# 22 2018-05-02 12:30:00  00:15:00
# 23 2018-05-02 12:45:00  00:15:00
# 24 2018-05-02 13:00:00  00:15:00
# 25 2018-05-02 13:15:00  00:15:00
# 26 2018-05-02 13:30:00  00:15:00
# 27 2018-05-02 13:45:00  00:15:00
# 28 2018-05-02 14:00:00  00:15:00
# 29 2018-05-02 14:15:00  00:15:00
# ..                 ...       ...
# 40 2018-05-03 10:15:00  00:15:00
# 41 2018-05-03 10:30:00  00:15:00
# 42 2018-05-03 10:45:00  00:15:00
# 43 2018-05-03 11:00:00  00:15:00
# 44 2018-05-03 11:15:00  00:15:00
# 45 2018-05-03 11:30:00  00:15:00
# 46 2018-05-03 11:45:00  00:15:00
# 47 2018-05-03 12:00:00  00:15:00
# 48 2018-05-03 12:15:00  00:15:00
# 49 2018-05-03 12:30:00  00:15:00
# 50 2018-05-03 12:45:00  00:15:00
# 51 2018-05-03 13:00:00  00:15:00
# 52 2018-05-03 13:15:00  00:15:00
# 53 2018-05-03 13:30:00  00:15:00
# 54 2018-05-03 13:45:00  00:15:00
# 55 2018-05-03 14:00:00  00:15:00
# 56 2018-05-03 14:15:00  00:15:00
# 57 2018-05-03 14:30:00  00:15:00
# 58 2018-05-03 14:45:00  00:15:00
# 59 2018-05-03 15:00:00  00:15:00
# 60 2018-05-03 15:15:00  00:15:00
# 61 2018-05-03 15:30:00  00:15:00
# 62 2018-05-03 15:45:00  00:15:00
# 63 2018-05-03 16:15:00  00:30:00
# 64 2018-05-04 09:30:00  17:15:00
# 65 2018-05-04 09:45:00  00:15:00
# 66 2018-05-04 10:00:00  00:15:00
# 67 2018-05-04 10:15:00  00:15:00
# 68 2018-05-04 10:30:00  00:15:00
# 69 2018-05-04 10:45:00  00:15:00
#
# [70 rows x 2 columns]

# %%
def conf(gb, pct = 0.9):
    mean = gb['return'].mean()
    count = gb['id'].count()
    sem = gb['return'].sem()
    conf = sem * scipy.stats.t.ppf((1 + pct) / 2., count-1)
    return conf.fillna(0)

# %%
fig, axes = plt.subplots(nrows = len(df_ret['TradeCategory'].unique()), ncols=1, figsize=(10, 75))
colors = {'-1': 'r', '1': 'g'}
for ax, tc in zip(axes.flatten(), df_ret['TradeCategory'].unique()):
    df_tc = df_ret[df_ret['TradeCategory'] == tc]
    gb = df_tc.groupby(['Result for Stock', 't'])
    
    conf_int = conf(gb, pct=0.75)
    mean = gb['return'].mean() 

    try:
        mean_plot = mean.unstack(level = 0).iloc[:,0]
        mean_plot.plot(marker='o', ax=ax, label = '-1', color = 'r') # plot the means
        
        conf_plot = conf_int.unstack(level = 0).iloc[:,0]
        conf_upper = conf_plot + mean_plot
        conf_lower = mean_plot - conf_plot
        
        ax.fill_between(mean_plot.index, mean_plot.values, conf_upper.values, color='r', alpha=0.25)
        ax.fill_between(mean_plot.index, conf_lower.values, mean_plot.values, color='r', alpha=0.25)
        
    except:
        print("%s: No data for '-1'" % tc)
        pass
    try:
        mean_plot = mean.unstack(level = 0).iloc[:,1]
        mean_plot.plot(marker='o', ax=ax, label = '1', color = 'g') # plot the means
        
        conf_plot = conf_int.unstack(level = 0).iloc[:,1]
        conf_upper = conf_plot + mean_plot
        conf_lower = mean_plot - conf_plot
        
        ax.fill_between(mean_plot.index, mean_plot.values, conf_upper.values, color='g', alpha=0.25)
        ax.fill_between(mean_plot.index, conf_lower.values, mean_plot.values, color='g', alpha=0.25)
        
    except:
        pass
    
    ax.set_autoscaley_on(True)
    ax.legend(loc='best')
    ax.set_title('%s, %d events' % (tc, len(df_tc.id.unique())))
plt.tight_layout()

# %%
df[df['TradeCategory'] == 'SHARED DRUG']
# Out:
#           Date EventTime  Ticker TradeCategory Result for Stock  \
# 141 2018-05-03  08:30:00    EGRX   SHARED DRUG                1
# 240 2018-05-17  16:30:00    ALDR   SHARED DRUG                1
# 323 2018-05-30  16:30:00    VRTX   SHARED DRUG               -1
# 461 2018-07-17  08:30:00  BTG LN   SHARED DRUG                1
# 474 2018-07-17  08:30:00     GE9   SHARED DRUG                1
# 478 2018-07-18  08:30:00    LGND   SHARED DRUG                1
# 482 2018-07-18  08:30:00    MNTA   SHARED DRUG               -1
# 509 2018-07-25  08:30:00    INVA   SHARED DRUG                1
# 525 2018-07-26  08:30:00    IRWD   SHARED DRUG                1
# 528 2018-07-27  08:30:00    ENTA   SHARED DRUG                1
# 576 2018-08-08  10:00:00     AGN   SHARED DRUG                1
# 577 2018-08-09  08:30:00    MNTA   SHARED DRUG               -1
#
#           EventDateTime   id
# 141 2018-05-03 08:30:00    7
# 240 2018-05-17 16:30:00   34
# 323 2018-05-30 16:30:00   48
# 461 2018-07-17 08:30:00   82
# 474 2018-07-17 08:30:00   83
# 478 2018-07-18 08:30:00   85
# 482 2018-07-18 08:30:00   86
# 509 2018-07-25 08:30:00   90
# 525 2018-07-26 08:30:00   94
# 528 2018-07-27 08:30:00   96
# 576 2018-08-08 10:00:00  106
# 577 2018-08-09 08:30:00  107
