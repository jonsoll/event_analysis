# %%
import importlib
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import math

import IntradayChartFormatter
importlib.reload(IntradayChartFormatter)
from IntradayChartFormatter import IntradayChartFormatter

# %%
def to_datetime(date, time):
    dt = ' '.join([date, time])
    return datetime.datetime.strptime(dt, "%m/%d/%Y %H:%M:%S")

# %% [markdown]
# ## Load and Preprocess

# %%
df = pd.read_excel('PowerQuery.xlsx')

# %%
df_reim = df[df['TradeCategory'] == 'REIMBURSEMENT']
df_reim = df_reim[df_reim['Position'].isin(['Long', 'Short'])]
df_reim = df_reim[~df_reim.EventTime.isna()]
df_reim.shape
# Out:
# (15, 16)

# %%
df_reim.loc[df_reim['EventTime'] == "BMO", 'EventTime'] = datetime.time(8, 30)
df_reim.loc[df_reim['EventTime'] == "AMC", 'EventTime'] = datetime.time(16, 30)

# %%
df_reim['EventDateTime'] = [datetime.datetime.combine(date, time) for (date, time) in zip(df_reim['Date'], df_reim['EventTime'])]

# %%
import IntradayPrice2
importlib.reload(IntradayPrice2)
from IntradayPrice2 import request_price_data

tickers        = df_reim['Ticker']
eventDatetimes = df_reim['EventDateTime']

request_price_data(tickers, eventDatetimes)
# Out:
# Connecting to localhost:8194
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-03T16:30:00.000
#     endDateTime = 2018-05-17T16:30:00.000
#     security = "FLXN Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-03T16:30:00.000
#     endDateTime = 2018-05-17T16:30:00.000
#     security = "HALO Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-03T16:30:00.000
#     endDateTime = 2018-05-17T16:30:00.000
#     security = "JAZZ Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-09T08:30:00.000
#     endDateTime = 2018-05-23T08:30:00.000
#     security = "COOL Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-09T08:30:00.000
#     endDateTime = 2018-05-23T08:30:00.000
#     security = "IART Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-09T08:30:00.000
#     endDateTime = 2018-05-23T08:30:00.000
#     security = "MDXG Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-09T08:30:00.000
#     endDateTime = 2018-05-23T08:30:00.000
#     security = "PCRX Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-09T08:30:00.000
#     endDateTime = 2018-05-23T08:30:00.000
#     security = "RHHBY Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-05-15T09:46:00.000
#     endDateTime = 2018-05-29T09:46:00.000
#     security = "XENT Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-07-26T08:30:00.000
#     endDateTime = 2018-08-09T08:30:00.000
#     security = "EYES Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-08-03T08:30:00.000
#     endDateTime = 2018-08-17T08:30:00.000
#     security = "JAZZ Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-08-07T08:30:00.000
#     endDateTime = 2018-08-21T08:30:00.000
#     security = "SOBI Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-10-25T14:00:00.000
#     endDateTime = 2018-11-08T14:00:00.000
#     security = "EGRX Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-10-25T14:00:00.000
#     endDateTime = 2018-11-08T14:00:00.000
#     security = "AMGN Equity"
# }
#
# IntradayBarRequest = {
#     eventType = TRADE
#     interval = 15
#     startDateTime = 2018-10-25T14:00:00.000
#     endDateTime = 2018-11-08T14:00:00.000
#     security = "REGN Equity"
# }
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f

# %%
data = {}
for tradeid, ticker, dt in zip(df_reim['DenovoTradeID'], df_reim['Ticker'], df_reim['EventDateTime']):
    print(ticker, '   =>    ', dt)
    
    try:
        pricedata = main(ticker, dt, daysPre = 1, daysPost = 1)
        data[repr(tradeid)] = pricedata
    except:
        print("Something went wrong.")
# Out:
# FLXN    =>     2018-05-03 16:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-02 16:30:00
# hello
# Session Closed
# HALO    =>     2018-05-03 16:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-02 16:30:00
# hello
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Session Closed
# JAZZ    =>     2018-05-03 16:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-02 16:30:00
# hello
# Session Closed
# COOL    =>     2018-05-09 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-08 08:30:00
# hello
# Session Closed
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# IART    =>     2018-05-09 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-08 08:30:00
# hello
# Session Closed
# MDXG    =>     2018-05-09 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-08 08:30:00
# hello
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Session Closed
# PCRX    =>     2018-05-09 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-08 08:30:00
# hello
# Session Closed
# RHHBY    =>     2018-05-09 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-08 08:30:00
# hello
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Session Closed
# XENT    =>     2018-05-15 09:46:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-05-14 09:46:00
# hello
# Session Closed
# EYES    =>     2018-07-26 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-07-25 08:30:00
# hello
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Session Closed
# JAZZ    =>     2018-08-03 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-08-02 08:30:00
# hello
# Session Closed
# SOBI    =>     2018-08-07 08:30:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-08-06 08:30:00
# hello
# Session Closed
# EGRX    =>     2018-10-25 14:00:00
#
#
# Connecting to localhost:8194
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Start Date = 2018-10-24 14:00:00
# hello
# Session Closed
# AMGN    =>     2018-10-25 14:00:00
#
#
# Connecting to localhost:8194
#
# Start Date = 2018-10-24 14:00:00
# hello
# Session Closed
# REGN    =>     2018-10-25 14:00:00
#
#
# Connecting to localhost:8194
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f
# Start Date = 2018-10-24 14:00:00
# hello
# Session Closed

# %%
fig, axes = plt.subplots(nrows=math.ceil(len(data) / 2), ncols=2, figsize = (14, 25))

for tradeid, ax in zip(data.keys(), axes.flatten()):
    price_data = data[tradeid]
    
    eventDateTime = pd.to_datetime(df_reim.loc[df_reim['DenovoTradeID'] == int(tradeid), 'EventDateTime'].item())
    price_data['eventFlag'] = 1*(price_data.index == min(price_data.index, key=lambda dt: abs(dt - eventDateTime)))   

    d_plot = price_data.copy()
    d_plot['x_ind'] = np.arange(len(d_plot))
    d_event = d_plot.loc[d_plot.eventFlag == 1,:]
    
#     formatter = IntradayChartFormatter(price_data.index)
#     ax.xaxis.set_major_formatter(formatter)
    ax.plot(d_plot.x_ind, d_plot.close, 'o-')
    ax.plot(d_event.x_ind, d_event.close, 'ro')
    ax.xaxis.set_visible(False)
    title = 'tradeid: ' + str(tradeid)
    ax.set_title(title)
